# %% [markdown]
# ### 데이터 시각화 기초

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='AppleGothic')
plt.rc('axes', unicode_minus=False)

# %%
plt.plot([10, 5, 25, 30, 20])
plt.title("직선 그래프 그리기: 한글처리")
plt.show()

# %%
plt.rcParams['figure.figsize']
# Out:
# [6.4, 4.8]

# %%
plt.rcParams['figure.figsize'] = (5, 2)
plt.rcParams['figure.figsize']
# Out:
# [5.0, 2.0]

# %%
plt.rcParams.update(plt.rcParamsDefault)
plt.rcParams['figure.figsize']
# Out:
# [6.4, 4.8]

# %%
plt.rcParams['figure.figsize'] = (5, 3)
plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False

plt.plot([1, 3, 5, 7, 9], [8, 6, 17, 22, 3])
plt.title("직선 그래프 그리기")
plt.show()

# %%
# 데이터 생성
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

plt.plot(x, y, marker='o', linestyle='-', color='b', label='소수(Prime Numbers)')

plt.xlabel("X-축(axis)")
plt.ylabel("Y-축(axis)")
plt.title("소수 그리기 (Prime Numbers Plot)")
plt.legend()

plt.show()

# %%
plt.plot([1, 2, 3, 4], [10, 20, 30, 40], color='r', linestyle='--', marker='d', linewidth=3, label='thick line')
plt.plot([1, 2, 3, 4], [40, 30, 20, 10], 'b', ls=':', marker='^', lw=0.5, label='thin line')

plt.title("속성 marker linewidth linestyle")
plt.xlabel("X-축(axis)")
plt.ylabel("Y-축(axis)")
plt.legend()

plt.show()

# %%
import numpy as np

np.random.seed(2025)

N = 80
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (20 * np.random.rand(N)) ** 2

plt.scatter(x, y, s=area,  c=colors, alpha=0.7)
plt.colorbar()
plt.show()

# %%
x = np.random.randint(-10, 10, 10)

print(x)
print(x > 0)
print(x[x>0])
# Out:
# [ -3  -4   1  -1   3   7  -9  -8   4 -10]
# [False False  True False  True  True False False  True False]
# [1 3 7 4]

# %%
x = np.random.randint(-100, 100, 1000)
y = np.random.randint(-100, 100, 1000)

mask1 = abs(x) > 50
mask2 = abs(y) > 50
x = x[mask1 + mask2]
y = y[mask1 + mask2]

plt.scatter(x, y, c=x, cmap='jet', alpha=0.4)
plt.colorbar()
plt.show()

# %%
x = np.random.randint(-100, 100, 1000)
y = np.random.randint(-100, 100, 1000)

mask1 = abs(x) > 50
mask2 = abs(y) > 50
x = x[mask1 * mask2]
y = y[mask1 * mask2]

plt.scatter(x, y, c=x, cmap='jet', alpha=0.4)
plt.colorbar()
plt.show()

# %% [markdown]
# 막대 그래프

# %%
plt.bar(["Red", "Green", "Blue"], [8, 5, 10])
plt.show()

# %%
c = ['red', 'green', 'blue']
plt.bar(c, [10, 4, 12], color=c, alpha=.4)
plt.show()

# %%
plt.figure(figsize=(6, 4))

plt.hist([1, 1, 1, 2, 2, 3, 4, 5, 6, 6, 6, 6], rwidth=.98, bins=[.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5])
plt.xticks(range(1, 7))

plt.show()

# %%
dice = np.random.choice(range(1, 7), 1000000, p=[0.15, 0.25, 0.3, 0.1, 0.1, 0.1])
plt.figure(figsize=(5, 3), dpi=200)

plt.hist(dice, rwidth=.98, bins=np.arange(.5, 7))
plt.xticks(range(1, 7))

plt.show()

# %%
plt.figure(figsize=(9, 4))

plt.subplot(2, 3, 1)
plt.plot([1, 2, 3])
plt.subplot(2, 3, 5)
plt.subplot(2, 3, 6)
plt.plot([5, 4, 3])

plt.show()

# %%
fig, axes = plt.subplots(2, 4)
fig.set_size_inches([9, 4])

axes[0, 1].plot([5, 1, 3])
axes[1, 0].plot([3, 3, 1])
plt.plot([10, 5, 20])
plt.show()

# %%
fig = plt.figure()

fig.add_subplot(321).set_title("321")
fig.add_subplot(322).set_title("322")
fig.add_subplot(323).set_title("323")
fig.add_subplot(324).set_title("324")
fig.add_subplot(325).set_title("325")
fig.add_subplot(326).set_title("326")

fig.subplots_adjust(wspace=.2, hspace=.7)
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(7, 5))

ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

plt.show()

# %%
fig = plt.figure(figsize=(7, 5))

ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

ax2.plot([1, 2, 3])
ax3.plot([3, 2, 1])
ax4.plot([3, 1, 2])

plt.show()

# %%
# 전체 제목 - 어느 위치에서 호출해도 무관
plt.suptitle("전체 제목", fontsize=14, y=1.02)

plt.subplot(2, 3, 1)
plt.plot([1, 4, 9, 16])
plt.title("제곱수")

plt.subplot(2, 3, 6)
plt.plot([1, 2, 3, 4])
plt.title("선형")

plt.subplot(2, 3, 2)
plt.plot([6, 5, 2, 1])
plt.title("감소")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(7, 4))
fig.set_size_inches(6, 3)

axes[0, 1].plot([1, 4, 9, 16])
axes[1, 0].plot([1, 2, 3, 4])
axes[1, 2].plot([6, 5, 2, 1])

fig.suptitle("전체 제목", fontsize=14, fontweight='bold')

axes[0, 0].set_title("(0, 0) 빈 플롯")
axes[0, 1].set_title("(0, 1) 제곱수")
axes[0, 2].set_title("(0, 2) 빈 플롯")
axes[1, 0].set_title("(1, 0) 선형")
axes[1, 1].set_title("(1, 1) 빈 플롯")
axes[1, 2].set_title("(1, 2) 감소")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(6, 4))

ax1 = fig.add_subplot(231)
ax1.plot([1, 4, 9, 16])
ax1.set_title("제곱수")

ax2 = fig.add_subplot(233)
ax2.plot([1, 2, 3, 4])
ax2.set_title("선형")

ax3 = fig.add_subplot(235)
ax3.plot([6, 5, 2, 1])
ax3.set_title("감소")

fig.suptitle("전체 제목", fontsize=14)
plt.tight_layout()
plt.show()
